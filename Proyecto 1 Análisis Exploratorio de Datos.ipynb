# %% [markdown]
# # Análisis Exploratorio de Datos

# %% [markdown]
# [DESCRIBCIÓN DE LAS BASES DE DATOS] -> Recordar que fue tomada del banco de datos del CEDE de la U. Los Andes

# %%
import pandas as pd
pd.set_option("max_columns", None) # Imprimir máximo de columnasn. 
pd.set_option("max_rows", None)    # Imprimir máximo de filas.

# %%
caracteristicas = pd.read_excel("/Users/juandmonjeh/Desktop/Machine Learning/PANEL_CARACTERISTICAS_GENERALES(2019).xlsx")
buen_gobierno = pd.read_excel("/Users/juandmonjeh/Desktop/Machine Learning/PANEL_BUEN_GOBIERNO(2019).xlsx")

# %%
caracteristicas.head(10)
# Out:
#    coddepto  codprovincia  codmpio      depto         provincia municipio  \
# 0         5           595     5001  Antioquia  Valle del aburra  Medellín
# 1         5           595     5001  Antioquia  Valle del aburra  Medellín
# 2         5           595     5001  Antioquia  Valle del aburra  Medellín
# 3         5           595     5001  Antioquia  Valle del aburra  Medellín
# 4         5           595     5001  Antioquia  Valle del aburra  Medellín
# 5         5           595     5001  Antioquia  Valle del aburra  Medellín
# 6         5           595     5001  Antioquia  Valle del aburra  Medellín
# 7         5           595     5001  Antioquia  Valle del aburra  Medellín
# 8         5           595     5001  Antioquia  Valle del aburra  Medellín
# 9         5           595     5001  Antioquia  Valle del aburra  Medellín
#
#     ano  ao_crea act_adm  gandina  gcaribe  gpacifica  gorinoquia  gamazonia  \
# ...

# %% [markdown]
# ## ¿Con qué datos se trabjarán?
#
# El _**Panel Municipal del CEDE**_ consolida información a nivel municipal de diferentes fuentes y entidades en una sola base de datos. El panel presenta información sobre:
#
# 1. Características generales de los municipios,
# 2. Variables fiscales y de buen gobierno,
# 3. Conflicto y violencia,
# 4. Educación,
# 5. Sector agrícola y,
# 6. Salud y servicios públicos.
#
# >Las fuentes principales son el *Departamento Administrativo Nacional de Estadística (DANE), Instituto Agustín Codazzi (IGAC), Departamento Nacional de Planeación (DNP), Ministerio de Agricultura, AGRONET, Ministerio de Salud, Ministerio de Minas y Energía*, entre otras.

# %%
caracteristicas2005=caracteristicas[caracteristicas["ano"]==2005]
buen_gobierno2005=buen_gobierno[buen_gobierno["ano"]==2005]

# %%
#######################
## Limpieza de bases ##
#######################

# Base -> Características Generales

caracteristicas2005=caracteristicas2005.dropna(axis=1,thresh=500) # Eliminaron las 10 columnas vacías de SISBEN

# %% [markdown]
# ## Preprocesamiento de Datos -> Limpieza y unión de bases

# %%
caracteristicas2005.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1122 entries, 12 to 29158
# Data columns (total 91 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coddepto            1122 non-null   int64
#  1   codprovincia        1122 non-null   int64
#  2   codmpio             1122 non-null   int64
#  3   depto               1122 non-null   object
#  4   provincia           1122 non-null   object
#  5   municipio           1122 non-null   object
#  6   ano                 1122 non-null   int64
#  7   ao_crea             1122 non-null   int64
#  8   act_adm             1119 non-null   object
#  9   gandina             1122 non-null   int64
#  10  gcaribe             1122 non-null   int64
#  11  gpacifica           1122 non-null   int64
#  12  gorinoquia          1122 non-null   int64
#  13  gamazonia           1122 non-null   int64
#  14  pobl_rur            1122 non-null   float64
# ...

# %%
caracteristicas2005.isna().sum()
# Out:
# coddepto                 0
# codprovincia             0
# codmpio                  0
# depto                    0
# provincia                0
# municipio                0
# ano                      0
# ao_crea                  0
# act_adm                  3
# gandina                  0
# gcaribe                  0
# gpacifica                0
# gorinoquia               0
# gamazonia                0
# pobl_rur                 0
# pobl_urb                 0
# pobl_tot                 0
# indrural                 4
# sisben3_pobl_1        1122
# sisben3_pobl_2        1122
# sisben3_pobl_3        1122
# sisben3_pobl_4        1122
# sisben3_pobl_5        1122
# sisben3_pobl_6        1122
# sisben3_pobl_7        1122
# sisben3_pobl_8        1122
# sisben3_pobl_9        1122
# sisben3_pobl_10       1122
# areaoficialkm2           0
# areaoficialhm2           0
# altura                   0
# discapital               0
# dismdo                   0
# disbogota                0
# ...

# %%
caracteristicas2005.isna().sum()
# Out:
# coddepto                0
# codprovincia            0
# codmpio                 0
# depto                   0
# provincia               0
# municipio               0
# ano                     0
# ao_crea                 0
# act_adm                 3
# gandina                 0
# gcaribe                 0
# gpacifica               0
# gorinoquia              0
# gamazonia               0
# pobl_rur                0
# pobl_urb                0
# pobl_tot                0
# indrural                4
# areaoficialkm2          0
# areaoficialhm2          0
# altura                  0
# discapital              0
# dismdo                  0
# disbogota               0
# codmdo                  0
# mercado_cercano         0
# distancia_mercado       0
# pib_cons               68
# pib_percapita_cons     69
# pib_agricola           25
# pib_industria          25
# pib_servicios          25
# pib_total              25
# pib_percapita          25
# gpc                    79
# ...

# %%
caracteristicas2005=caracteristicas2005[caracteristicas2005["pib_cons"].notna()]
caracteristicas2005.isna().sum()
# Out:
# coddepto                0
# codprovincia            0
# codmpio                 0
# depto                   0
# provincia               0
# municipio               0
# ano                     0
# ao_crea                 0
# act_adm                 3
# gandina                 0
# gcaribe                 0
# gpacifica               0
# gorinoquia              0
# gamazonia               0
# pobl_rur                0
# pobl_urb                0
# pobl_tot                0
# indrural                0
# areaoficialkm2          0
# areaoficialhm2          0
# altura                  0
# discapital              0
# dismdo                  0
# disbogota               0
# codmdo                  0
# mercado_cercano         0
# distancia_mercado       0
# pib_cons                0
# pib_percapita_cons      1
# pib_agricola            0
# pib_industria           0
# pib_servicios           0
# pib_total               0
# pib_percapita           0
# gpc                    42
# ...

# %%
caracteristicas2005=caracteristicas2005[caracteristicas2005["gpc"].notna()]
caracteristicas2005.isna().sum()
# Out:
# coddepto                0
# codprovincia            0
# codmpio                 0
# depto                   0
# provincia               0
# municipio               0
# ano                     0
# ao_crea                 0
# act_adm                 3
# gandina                 0
# gcaribe                 0
# gpacifica               0
# gorinoquia              0
# gamazonia               0
# pobl_rur                0
# pobl_urb                0
# pobl_tot                0
# indrural                0
# areaoficialkm2          0
# areaoficialhm2          0
# altura                  0
# discapital              0
# dismdo                  0
# disbogota               0
# codmdo                  0
# mercado_cercano         0
# distancia_mercado       0
# pib_cons                0
# pib_percapita_cons      0
# pib_agricola            0
# pib_industria           0
# pib_servicios           0
# pib_total               0
# pib_percapita           0
# gpc                     0
# ...

# %%
varemover=["act_adm","minorias","parques","religioso","estado","otras"]
caracteristicas2005=caracteristicas2005.drop(varemover,axis=1)
caracteristicas2005.isna().sum()
# Out:
# coddepto              0
# codprovincia          0
# codmpio               0
# depto                 0
# provincia             0
# municipio             0
# ano                   0
# ao_crea               0
# gandina               0
# gcaribe               0
# gpacifica             0
# gorinoquia            0
# gamazonia             0
# pobl_rur              0
# pobl_urb              0
# pobl_tot              0
# indrural              0
# areaoficialkm2        0
# areaoficialhm2        0
# altura                0
# discapital            0
# dismdo                0
# disbogota             0
# codmdo                0
# mercado_cercano       0
# distancia_mercado     0
# pib_cons              0
# pib_percapita_cons    0
# pib_agricola          0
# pib_industria         0
# pib_servicios         0
# pib_total             0
# pib_percapita         0
# gpc                   0
# gini                  0
# pobreza               0
# nbi                   1
# nbicabecera           1
# ...

# %%
caracteristicas2005=caracteristicas2005[caracteristicas2005["nbi"].notna()]
caracteristicas2005.isna().sum()
# Out:
# coddepto              0
# codprovincia          0
# codmpio               0
# depto                 0
# provincia             0
# municipio             0
# ano                   0
# ao_crea               0
# gandina               0
# gcaribe               0
# gpacifica             0
# gorinoquia            0
# gamazonia             0
# pobl_rur              0
# pobl_urb              0
# pobl_tot              0
# indrural              0
# areaoficialkm2        0
# areaoficialhm2        0
# altura                0
# discapital            0
# dismdo                0
# disbogota             0
# codmdo                0
# mercado_cercano       0
# distancia_mercado     0
# pib_cons              0
# pib_percapita_cons    0
# pib_agricola          0
# pib_industria         0
# pib_servicios         0
# pib_total             0
# pib_percapita         0
# gpc                   0
# gini                  0
# pobreza               0
# nbi                   0
# nbicabecera           0
# ...

# %%
caracteristicas2005=caracteristicas2005[caracteristicas2005["IPM_urb"].notna()]
caracteristicas2005.isna().sum()
# Out:
# coddepto              0
# codprovincia          0
# codmpio               0
# depto                 0
# provincia             0
# municipio             0
# ano                   0
# ao_crea               0
# gandina               0
# gcaribe               0
# gpacifica             0
# gorinoquia            0
# gamazonia             0
# pobl_rur              0
# pobl_urb              0
# pobl_tot              0
# indrural              0
# areaoficialkm2        0
# areaoficialhm2        0
# altura                0
# discapital            0
# dismdo                0
# disbogota             0
# codmdo                0
# mercado_cercano       0
# distancia_mercado     0
# pib_cons              0
# pib_percapita_cons    0
# pib_agricola          0
# pib_industria         0
# pib_servicios         0
# pib_total             0
# pib_percapita         0
# gpc                   0
# gini                  0
# pobreza               0
# nbi                   0
# nbicabecera           0
# ...

# %%
caracteristicas2005.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1010 entries, 12 to 27208
# Data columns (total 75 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coddepto            1010 non-null   int64
#  1   codprovincia        1010 non-null   int64
#  2   codmpio             1010 non-null   int64
#  3   depto               1010 non-null   object
#  4   provincia           1010 non-null   object
#  5   municipio           1010 non-null   object
#  6   ano                 1010 non-null   int64
#  7   ao_crea             1010 non-null   int64
#  8   gandina             1010 non-null   int64
#  9   gcaribe             1010 non-null   int64
#  10  gpacifica           1010 non-null   int64
#  11  gorinoquia          1010 non-null   int64
#  12  gamazonia           1010 non-null   int64
#  13  pobl_rur            1010 non-null   float64
#  14  pobl_urb            1010 non-null   float64
# ...

# %%
caracteristicas2005.head(10)
# Out:
#      coddepto  codprovincia  codmpio      depto         provincia  \
# 12          5           595     5001  Antioquia  Valle del aburra
# 38          5           562     5002  Antioquia           Oriente
# 64          5           560     5004  Antioquia         Occidente
# 90          5           562     5021  Antioquia           Oriente
# 116         5           585     5030  Antioquia          Suroeste
# 142         5           556     5031  Antioquia          Nordeste
# 168         5           585     5034  Antioquia          Suroeste
# 194         5           585     5036  Antioquia          Suroeste
# 220         5           558     5038  Antioquia             Norte
# 246         5           556     5040  Antioquia          Nordeste
#
#        municipio   ano  ao_crea  gandina  gcaribe  gpacifica  gorinoquia  \
# 12      Medellín  2005     1675        1        0          0           0
# 38     Abejorral  2005     1814        1        0          0           0
# ...

# %%
buen_gobierno2005.head(10)
# Out:
#      codmpio   ano      y_total       y_corr  y_corr_tribut  \
# 21    5001.0  2005  1642978.646  1164728.001     627525.376
# 57    5002.0  2005     6160.883     1410.550        748.617
# 93    5004.0  2005     2637.525      535.449        131.007
# 129   5021.0  2005     4749.492     1101.681        292.977
# 165   5030.0  2005     8169.280     3182.519       1754.434
# 201   5031.0  2005     9436.184     2646.726       1516.748
# 237   5034.0  2005    12698.723     4432.424       2621.284
# 273   5036.0  2005     3035.725      735.152        212.493
# 309   5038.0  2005     6619.128     1571.120        522.658
# 345   5040.0  2005     8726.965     2753.608       2078.222
#
#      y_corr_tribut_predial  y_corr_tribut_IyC  y_corr_tribut_gasol  \
# 21              260274.015         188622.448            80976.107
# 57                 284.765            290.508               69.490
# 93                  37.966             67.200                0.000
# ...

# %%
buen_gobierno2005["codmpio"]=buen_gobierno2005["codmpio"].astype("int64")
buen_gobierno2005.info(verbose=True,null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1122 entries, 21 to 40164
# Data columns (total 121 columns):
#  #    Column                 Non-Null Count  Dtype
# ---   ------                 --------------  -----
#  0    codmpio                1122 non-null   int64
#  1    y_total                1097 non-null   float64
#  2    y_corr                 1097 non-null   float64
#  3    y_corr_tribut          1101 non-null   float64
#  4    y_corr_tribut_predial  1097 non-null   float64
#  5    y_corr_tribut_IyC      1097 non-null   float64
#  6    y_corr_tribut_gasol    1087 non-null   float64
#  7    y_corr_tribut_otros_2  1085 non-null   float64
#  8    y_no_tribut            1097 non-null   float64
#  9    y_transf               1097 non-null   float64
#  10   y_transf_nal           1097 non-null   float64
#  11   y_transf_otra          1097 non-null   float64
#  12   g_total                1097 non-null   float64
#  13   g_corr                 1097 non-null   float64
# ...

# %%
buen_gobierno2005.isna().sum()
# Out:
# codmpio                  0
# y_total                  0
# y_corr                   0
# y_corr_tribut            0
# y_corr_tribut_predial    0
# y_corr_tribut_IyC        0
# y_corr_tribut_gasol      0
# y_corr_tribut_otros_2    0
# y_no_tribut              0
# y_transf                 0
# y_transf_nal             0
# y_transf_otra            0
# g_total                  0
# g_corr                   0
# g_func                   0
# g_func_personal          0
# g_func_general           0
# g_func_trans             0
# g_int_deudap             0
# deficit                  0
# y_cap                    0
# y_cap_regalias           0
# y_cap_transf             0
# y_cap_cofinan            0
# y_cap_otros              0
# g_cap                    0
# g_cap_FBKF               0
# g_cap_resto              0
# deficit_total            0
# finan                    0
# finan_credito            0
# finan_credito_desemb     0
# finan_credito_amort      0
# finan_credito_balance    0
# ...

# %%
buen_gobierno2005=buen_gobierno2005.drop("ano",axis=1)

# %%
buen_gobierno2005=buen_gobierno2005.dropna(axis=1,thresh=500) 
# Con esta línea se eliminaron las 10 columnas vacías de SISBEN

# %%
buen_gobierno2005=buen_gobierno2005[buen_gobierno2005["y_total"].notna()]

# %%
buen_gobierno2005.info(verbose=True,null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1039 entries, 21 to 40164
# Data columns (total 121 columns):
#  #    Column                 Non-Null Count  Dtype
# ---   ------                 --------------  -----
#  0    codmpio                1039 non-null   int64
#  1    y_total                1039 non-null   float64
#  2    y_corr                 1039 non-null   float64
#  3    y_corr_tribut          1039 non-null   float64
#  4    y_corr_tribut_predial  1039 non-null   float64
#  5    y_corr_tribut_IyC      1039 non-null   float64
#  6    y_corr_tribut_gasol    1039 non-null   float64
#  7    y_corr_tribut_otros_2  1039 non-null   float64
#  8    y_no_tribut            1039 non-null   float64
#  9    y_transf               1039 non-null   float64
#  10   y_transf_nal           1039 non-null   float64
#  11   y_transf_otra          1039 non-null   float64
#  12   g_total                1039 non-null   float64
#  13   g_corr                 1039 non-null   float64
# ...

# %%
buen_gobierno2005=buen_gobierno2005[buen_gobierno2005["y_corr_tribut_gasol"].notna()]

# %%
buen_gobierno2005=buen_gobierno2005[buen_gobierno2005["y_corr_tribut_otros_2"].notna()]

# %%
buen_gobierno2005=buen_gobierno2005[buen_gobierno2005["DF_ing_func"].notna()]

# %%
buen_gobierno2005=buen_gobierno2005[buen_gobierno2005["categoria"].notna()]

# %%
buen_gobierno2005=buen_gobierno2005[buen_gobierno2005["indesarrollo_dep"].notna()]

# %%
base_comple=pd.merge(caracteristicas2005,buen_gobierno2005,on="codmpio")
base_comple.info(verbose=True,null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1038 entries, 0 to 1037
# Data columns (total 201 columns):
#  #    Column                 Non-Null Count  Dtype
# ---   ------                 --------------  -----
#  0    coddepto               1038 non-null   int64
#  1    codprovincia           1038 non-null   int64
#  2    codmpio                1038 non-null   int64
#  3    depto                  1038 non-null   object
#  4    provincia              1038 non-null   object
#  5    municipio              1038 non-null   object
#  6    ano                    1038 non-null   int64
#  7    ao_crea                1038 non-null   int64
#  8    act_adm                1035 non-null   object
#  9    gandina                1038 non-null   int64
#  10   gcaribe                1038 non-null   int64
#  11   gpacifica              1038 non-null   int64
#  12   gorinoquia             1038 non-null   int64
#  13   gamazonia              1038 non-null   int64
# ...

# %%
base
